# %%
# !bash ./extract.sh
# Out:
# Parent folder: 20240227/双边界垂直（左车右车）_可泊宽度3m_左侧泊入
# dest dir: log_15点48
# Full path: 20240227/双边界垂直（左车右车）_可泊宽度3m_左侧泊入/log_15点48.tar.gz
# dst path: 20240227/双边界垂直（左车右车）_可泊宽度3m_左侧泊入/log_15点48
# log/diagnostic.log
# log/diagnostic0.log
# log/diagnostic1.log
# log/diagnostic2.log
# log/dm_cache/
# log/dm_cache/tmq_msg_recorder_2024-02-27-15-46-04/
# log/dm_cache/tmq_msg_recorder_2024-02-27-15-46-04/2024-02-27-15-46-04/
# log/dm_cache/tmq_msg_recorder_2024-02-27-15-46-04/2024-02-27-15-46-04/0.tbag
# log/dm_cache/tmq_msg_recorder_2024-02-27-15-46-04/2024-02-27-15-46-04/meta.json
# log/dm_cache/tmq_msg_recorder_2024-02-27-15-46-04/2024-02-27-15-46-04/1.tbag
# log/dm_cache/dtc_data/
# log/dm_cache/dtc_data/diagnostic_actions.bin
# log/dm_cache/tmq_msg_recorder_2024-02-27-15-49-41/
# log/dm_cache/tmq_msg_recorder_2024-02-27-15-49-41/2024-02-27-15-49-41/
# log/dm_cache/tmq_msg_recorder_2024-02-27-15-49-41/2024-02-27-15-49-41/0.tbag
# ...
