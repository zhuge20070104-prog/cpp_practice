# %%
# 在sales.csv中查找16位的Visa号
# 打印Visa号
# 每四个数字加上 -

# 生成sales.csv
cmd='''
for i in {0..9}; do
    echo "visa,3111${i}111111111" >> sales.csv
done
'''
# !{cmd}

# %%
# 查找visa号，并加上 - 的代码

# !bash ./cat_credit_num.sh
# Out:
# 1111-1111-1111-1110
# 1111-1111-1111-1111
# 1111-1111-1111-1112
# 1111-1111-1111-1113
# 1111-1111-1111-1114
# 1111-1111-1111-1115
# 1111-1111-1111-1116
# 1111-1111-1111-1117
# 1111-1111-1111-1118
# 1111-1111-1111-1119
# 2111-1111-1111-1110
# 2111-1111-1111-1111
# 2111-1111-1111-1112
# 2111-1111-1111-1113
# 2111-1111-1111-1114
# 2111-1111-1111-1115
# 2111-1111-1111-1116
# 2111-1111-1111-1117
# 2111-1111-1111-1118
# 2111-1111-1111-1119
# 2111-1111-1111-1103
# 2111-1111-1111-1113
# 2111-1111-1111-1123
# 2111-1111-1111-1133
# 2111-1111-1111-1143
# 2111-1111-1111-1153
# 2111-1111-1111-1163
# 2111-1111-1111-1173
# 2111-1111-1111-1183
# 2111-1111-1111-1193
# 3111-0111-1111-1113
# 3111-1111-1111-1113
# 3111-2111-1111-1113
# 3111-3111-1111-1113
# 3111-4111-1111-1113
# 3111-5111-1111-1113
# 3111-6111-1111-1113
# 3111-7111-1111-1113
# 3111-8111-1111-1113
# 3111-9111-1111-1113
