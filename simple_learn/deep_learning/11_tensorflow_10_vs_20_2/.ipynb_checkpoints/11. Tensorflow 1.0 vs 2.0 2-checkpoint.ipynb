# %%
# Import the necessary libraries

import datetime, warnings, scipy
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.rcParams['patch.force_edgecolor'] = True
plt.style.use('fivethirtyeight')
mpl.rc('patch', edgecolor='dimgray', linewidth=1)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'last_expr'
pd.options.display.max_columns = 50
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
# 2. import keras 和 sklearn相关包
# https://keras.io/api/layers
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error

# %%
# 5. 读取和查看数据集

df = pd.read_csv('./air_quality.csv', sep=' ')
df.head()
# Out:
#    No  Profile     Tanggal       Jam     O3    CO    NO2    SO2      NO  \
# 0   1  BANDUNG  2019-05-19  00:04:19  21.35  0.78   6.77  14.06  26.168
# 1   2  BANDUNG  2019-05-19  00:15:01   5.93  0.82  14.87  17.23  53.853
# 2   3  BANDUNG  2019-05-19  00:30:06   6.62  0.63  22.24   2.31  38.304
# 3   4  BANDUNG  2019-05-19  00:49:19  13.29  0.44  19.00   5.32  18.962
# 4   5  BANDUNG  2019-05-19  01:04:19   2.44  0.47  26.74  13.61  35.270
#
#       CO2      VOC  PM1  PM2.5  PM4   PM10  TSP  TEMP    HUM     WS  WD  ISPU  \
# 0  409.86  251.202  0.0    0.0  0.0   2.77  0.0  21.4  100.0  0.600   5     9
# 1  394.79  501.356  0.0    0.0  0.0  11.95  0.0  42.6  200.0  0.000   2    12
# 2  390.66  753.291  0.0    0.0  0.0  12.71  0.0  63.6  299.2  0.000   2    13
# 3  401.23  251.043  0.0    0.0  0.0   1.20  0.0  21.3   88.2  0.525   5     6
# 4  381.67  250.471  0.0    0.0  0.0   3.52  0.0  21.3   97.4  0.975   5     9
#
#   Status  Unnamed: 22
# 0   BAIK          NaN
# 1   BAIK          NaN
# 2   BAIK          NaN
# 3   BAIK          NaN
# 4   BAIK          NaN

# %%
# 6. head可以带参数滴，指定拿几行值
df.head(3)
# Out:
#    No  Profile     Tanggal       Jam     O3    CO    NO2    SO2      NO  \
# 0   1  BANDUNG  2019-05-19  00:04:19  21.35  0.78   6.77  14.06  26.168
# 1   2  BANDUNG  2019-05-19  00:15:01   5.93  0.82  14.87  17.23  53.853
# 2   3  BANDUNG  2019-05-19  00:30:06   6.62  0.63  22.24   2.31  38.304
#
#       CO2      VOC  PM1  PM2.5  PM4   PM10  TSP  TEMP    HUM   WS  WD  ISPU  \
# 0  409.86  251.202  0.0    0.0  0.0   2.77  0.0  21.4  100.0  0.6   5     9
# 1  394.79  501.356  0.0    0.0  0.0  11.95  0.0  42.6  200.0  0.0   2    12
# 2  390.66  753.291  0.0    0.0  0.0  12.71  0.0  63.6  299.2  0.0   2    13
#
#   Status  Unnamed: 22
# 0   BAIK          NaN
# 1   BAIK          NaN
# 2   BAIK          NaN

# %%
# 7. 将时间转换成DateTime类型的函数, 仅保留到小时
def combine_date(df, tab_name):
    list_tab = []
    for i in range(df.shape[0]):
        list_tab.append(df.loc[i, 'Tanggal'] + 'T' + df.loc[i, tab_name][0:2])
    return np.array(list_tab, dtype='datetime64')

# 应该有一列Datetime了
df['Datetime'] = combine_date(df, 'Jam')
df.head()
# Out:
#    No  Profile     Tanggal       Jam     O3    CO    NO2    SO2      NO  \
# 0   1  BANDUNG  2019-05-19  00:04:19  21.35  0.78   6.77  14.06  26.168
# 1   2  BANDUNG  2019-05-19  00:15:01   5.93  0.82  14.87  17.23  53.853
# 2   3  BANDUNG  2019-05-19  00:30:06   6.62  0.63  22.24   2.31  38.304
# 3   4  BANDUNG  2019-05-19  00:49:19  13.29  0.44  19.00   5.32  18.962
# 4   5  BANDUNG  2019-05-19  01:04:19   2.44  0.47  26.74  13.61  35.270
#
#       CO2      VOC  PM1  PM2.5  PM4   PM10  TSP  TEMP    HUM     WS  WD  ISPU  \
# 0  409.86  251.202  0.0    0.0  0.0   2.77  0.0  21.4  100.0  0.600   5     9
# 1  394.79  501.356  0.0    0.0  0.0  11.95  0.0  42.6  200.0  0.000   2    12
# 2  390.66  753.291  0.0    0.0  0.0  12.71  0.0  63.6  299.2  0.000   2    13
# 3  401.23  251.043  0.0    0.0  0.0   1.20  0.0  21.3   88.2  0.525   5     6
# 4  381.67  250.471  0.0    0.0  0.0   3.52  0.0  21.3   97.4  0.975   5     9
#
#   Status  Unnamed: 22            Datetime
# 0   BAIK          NaN 2019-05-19 00:00:00
# 1   BAIK          NaN 2019-05-19 00:00:00
# 2   BAIK          NaN 2019-05-19 00:00:00
# 3   BAIK          NaN 2019-05-19 00:00:00
# 4   BAIK          NaN 2019-05-19 01:00:00

# %%
# 8. 只要部分列， Convert into hourly Data

df = df [['Datetime', 'O3', 'CO', 'NO2', 'SO2', 'NO', 'CO2', 'VOC', 'PM1', 'PM2.5', 'PM4', 'PM10', 'TSP', 'TEMP', 'HUM', 'WS', 'WD', 'ISPU']]

df.head()
# Out:
#              Datetime     O3    CO    NO2    SO2      NO     CO2      VOC  \
# 0 2019-05-19 00:00:00  21.35  0.78   6.77  14.06  26.168  409.86  251.202
# 1 2019-05-19 00:00:00   5.93  0.82  14.87  17.23  53.853  394.79  501.356
# 2 2019-05-19 00:00:00   6.62  0.63  22.24   2.31  38.304  390.66  753.291
# 3 2019-05-19 00:00:00  13.29  0.44  19.00   5.32  18.962  401.23  251.043
# 4 2019-05-19 01:00:00   2.44  0.47  26.74  13.61  35.270  381.67  250.471
#
#    PM1  PM2.5  PM4   PM10  TSP  TEMP    HUM     WS  WD  ISPU
# 0  0.0    0.0  0.0   2.77  0.0  21.4  100.0  0.600   5     9
# 1  0.0    0.0  0.0  11.95  0.0  42.6  200.0  0.000   2    12
# 2  0.0    0.0  0.0  12.71  0.0  63.6  299.2  0.000   2    13
# 3  0.0    0.0  0.0   1.20  0.0  21.3   88.2  0.525   5     6
# 4  0.0    0.0  0.0   3.52  0.0  21.3   97.4  0.975   5     9

# %%
# 9. 按小时groupBy, 求平均数

df2 = df.groupby(['Datetime']).mean()
df2.head()
# Out:
#                             O3        CO     NO2      SO2        NO  \
# Datetime
# 2019-05-19 00:00:00  11.797500  0.667500  15.720   9.7300  34.32175
# 2019-05-19 01:00:00   3.816667  0.373333  22.600  20.0900  39.82100
# 2019-05-19 02:00:00   6.450000  0.332500  24.130  26.3100  51.29325
# 2019-05-19 03:00:00   4.740000  0.180000  25.975  24.3900  43.51850
# 2019-05-19 04:00:00  19.692500  0.202500  20.395  18.6225  53.37925
#
#                             CO2        VOC  PM1  PM2.5  PM4      PM10  TSP  \
# Datetime
# 2019-05-19 00:00:00  399.135000  439.22300  0.0    0.0  0.0  7.157500  0.0
# 2019-05-19 01:00:00  388.536667  250.39400  0.0    0.0  0.0  3.293333  0.0
# 2019-05-19 02:00:00  396.242500  251.04575  0.0    0.0  0.0  6.487500  0.0
# 2019-05-19 03:00:00  401.355000  252.24875  0.0    0.0  0.0  4.700000  0.0
# 2019-05-19 04:00:00  399.335000  694.23975  0.0    0.0  0.0  5.262500  0.0
#
#                           TEMP         HUM       WS        WD       ISPU
# Datetime
# 2019-05-19 00:00:00  37.225000  171.850000  0.28125  3.500000  10.000000
# 2019-05-19 01:00:00  20.966667   95.033333  0.67500  4.666667  12.666667
# 2019-05-19 02:00:00  20.150000   97.500000  0.09375  3.750000  16.250000
# 2019-05-19 03:00:00  19.850000  100.000000  0.07500  5.000000  15.000000
# 2019-05-19 04:00:00  53.475000  272.500000  0.18750  5.250000  13.250000

# %%
# 10. 看下df2的统计值
df2.describe()
# Out:
#                 O3           CO          NO2          SO2           NO  \
# count  1737.000000  1737.000000  1737.000000  1737.000000  1737.000000
# mean      8.538909     0.233172    16.681910    12.013894    37.086256
# std       3.997292     0.388102     5.373487     4.411251    12.521778
# min       0.270000     0.010000     2.040000     2.162500     3.128750
# 25%       5.881667     0.083333    13.010000     9.015000    28.443500
# 50%       7.813333     0.160000    15.916667    11.730000    39.252250
# 75%      10.373333     0.296667    19.935000    14.595000    46.015500
# max      33.741667    13.950000    99.600000    46.290000   194.554000
#
#                CO2          VOC          PM1        PM2.5          PM4  \
# count  1737.000000  1737.000000  1737.000000  1737.000000  1737.000000
# mean    394.616480   260.053778     0.309564     0.383692     0.451982
# std       4.180224    60.773321     2.286104     2.874126     3.378291
# min     380.420000   187.518000     0.000000     0.000000     0.000000
# 25%     391.830000   247.798333     0.000000     0.000000     0.000000
# 50%     394.602000   250.926250     0.000000     0.000000     0.000000
# 75%     397.415000   253.286667     0.000000     0.000000     0.000000
# max     408.820000  1240.713500    51.600000    68.700000    79.800000
#
#               PM10          TSP         TEMP          HUM           WS  \
# count  1737.000000  1737.000000  1737.000000  1737.000000  1737.000000
# mean      6.157770     0.562012    25.266942    77.634191    24.291226
# std       4.149511     4.184787     6.707977    29.743129    51.993683
# min       0.885000     0.000000    11.250000    26.866667     0.000000
# 25%       4.340000     0.000000    21.266667    57.850000     0.237500
# 50%       5.571667     0.000000    24.100000    77.083333     1.312500
# 75%       7.090000     0.000000    28.400000    94.066667     5.075000
# max      91.600000    92.900000   124.600000   313.400000   199.200000
#
#                 WD         ISPU
# count  1737.000000  1737.000000
# mean      7.129031    10.097848
# std       3.523245     5.049788
# min       0.000000     4.250000
# 25%       4.666667     8.166667
# 50%       5.833333     9.500000
# 75%      10.500000    11.000000
# max      15.000000   156.500000

# %%
# 11. 计算quantile [计算分位数，这里是4分位数]
def calculate_quantile(i, df2):
    Q1 = df2[[i]].quantile(0.25)[0]
    Q3 = df2[[i]].quantile(0.75)[0]
    IQR = Q3 - Q1
    min = df2[[i]].min()[0]
    max = df2[[i]].max()[0]
    min_IQR = Q1 - 1.5* IQR
    max_IQR = Q3 + 1.5* IQR
    return Q1, Q3, min, max, min_IQR, max_IQR

# %%
# 查找并插值异常值
# min_IQR
# max_IQR,
# 超过这个范围的值就是异常值
# https://www.cnblogs.com/Neo007/p/7594491.html


# 12. 去掉异常值
# 过程就是先算 min_IQR和max_IQR,
# 然后把 < min_IQR和 > max_IQR的值找出来，替换成np.nan
# 接着使用线性回归插值，插入新值
# 因为这些脏数据可能是因为传感器错误产生的，会影响结果
    
df2.drop(index=[df2.index[0], df2.index[df2.shape[0]-1]], inplace=True)
for i in df2.columns:
    print('\nAttribute-', i, ':')
    Q1, Q3, min, max, min_IQR, max_IQR = calculate_quantile(i, df2)
    print('Q1 = %.2f' % Q1)
    print('Q3 = %.2f' % Q3)
    print('min IQR = %.2f' % min_IQR)
    print('max IQR = %.2f' % max_IQR)
    if min < min_IQR:
        print('---> Low outlier is found = %.2f' % min)
    if max > max_IQR:
        print('---> High outlier is found = %.2f' % max)
    
    def convert_nan(x, max_IQR=max_IQR, min_IQR=min_IQR):
        if ((x > max_IQR) | (x<min_IQR)):
            x = np.nan
        else:
            x = x
        return x
    
    # HUM列的最大值是100，不是max_IQR
    def convert_nan_HUM(x, max_IQR=100.0, min_IQR=min_IQR):
        if ((x > max_IQR) | (x<min_IQR)):
            x = np.nan
        else:
            x = x
        return x
    
  
    
    if i=='HUM':
        df2[i] = df2[i].map(convert_nan_HUM)
        if len(df2[df2[i].isnull()][i]) > 0:
            print('######## HAS Outliers  #########')
        df2[i] = df2[i].interpolate(method='linear')
    else:
        df2[i] = df2[i].map(convert_nan)
        if len(df2[df2[i].isnull()][i]) > 0:
            print('######## HAS Outliers  #########')
        df2[i] = df2[i].interpolate(method='linear')
    
    if len(df2[df2[i].isnull()][i]) == 0:
        print('######## Outliers have been interpolated #########')
# Out:
# Attribute- O3 :
# Q1 = 5.88
# Q3 = 10.37
# min IQR = -0.85
# max IQR = 17.10
# ---> High outlier is found = 33.74
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- CO :
# Q1 = 0.08
# Q3 = 0.30
# min IQR = -0.24
# max IQR = 0.62
# ---> High outlier is found = 13.95
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- NO2 :
# Q1 = 13.01
# Q3 = 19.94
# min IQR = 2.62
# max IQR = 30.32
# ---> Low outlier is found = 2.04
# ---> High outlier is found = 99.60
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- SO2 :
# Q1 = 9.00
# Q3 = 14.61
# min IQR = 0.60
# max IQR = 23.01
# ---> High outlier is found = 46.29
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- NO :
# Q1 = 28.44
# Q3 = 46.02
# min IQR = 2.09
# max IQR = 72.37
# ---> High outlier is found = 194.55
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- CO2 :
# Q1 = 391.83
# Q3 = 397.41
# min IQR = 383.47
# max IQR = 405.77
# ---> Low outlier is found = 380.42
# ---> High outlier is found = 408.82
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- VOC :
# Q1 = 247.80
# Q3 = 253.29
# min IQR = 239.57
# max IQR = 261.52
# ---> Low outlier is found = 187.52
# ---> High outlier is found = 1240.71
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- PM1 :
# Q1 = 0.00
# Q3 = 0.00
# min IQR = 0.00
# max IQR = 0.00
# ---> High outlier is found = 51.60
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- PM2.5 :
# Q1 = 0.00
# Q3 = 0.00
# min IQR = 0.00
# max IQR = 0.00
# ---> High outlier is found = 68.70
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- PM4 :
# Q1 = 0.00
# Q3 = 0.00
# min IQR = 0.00
# max IQR = 0.00
# ---> High outlier is found = 79.80
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- PM10 :
# Q1 = 4.34
# Q3 = 7.08
# min IQR = 0.22
# max IQR = 11.20
# ---> High outlier is found = 91.60
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- TSP :
# Q1 = 0.00
# Q3 = 0.00
# min IQR = 0.00
# max IQR = 0.00
# ---> High outlier is found = 92.90
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- TEMP :
# Q1 = 21.27
# Q3 = 28.40
# min IQR = 10.57
# max IQR = 39.10
# ---> High outlier is found = 124.60
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- HUM :
# Q1 = 57.83
# Q3 = 94.06
# min IQR = 3.50
# max IQR = 148.40
# ---> High outlier is found = 313.40
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- WS :
# Q1 = 0.24
# Q3 = 5.06
# min IQR = -7.00
# max IQR = 12.30
# ---> High outlier is found = 199.20
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########
#
# Attribute- WD :
# Q1 = 4.67
# Q3 = 10.55
# min IQR = -4.16
# max IQR = 19.38
# ######## Outliers have been interpolated #########
#
# Attribute- ISPU :
# Q1 = 8.17
# Q3 = 11.00
# min IQR = 3.92
# max IQR = 15.25
# ---> High outlier is found = 156.50
# ######## HAS Outliers  #########
# ######## Outliers have been interpolated #########

# %%
# 13. 处理倾斜数据

# loge(x + 1)
# log transformation to deal with skewed data
dataset = np.log1p(df2[['TEMP']].values)
dataset.shape
dataset[0:10]
# Out:
# array([[3.08952615],
#        [3.05163991],
#        [3.03735395],
#        [2.99322914],
#        [2.9470671 ],
#        [2.98946266],
#        [3.14415228],
#        [3.22585144],
#        [3.3259349 ],
#        [3.41690668]])

# %%
# 使用matplotlib画一下
dist_df = pd.DataFrame({'TEMP': df2['TEMP'].values, 'log_TEMP': dataset[:, 0]})
# Histogram plot original vs log transform data
plt.figure(figsize=(12, 5))
dist_df.hist();

# %%
# 14. train_test_split

train_size = int(len(dataset) * 0.75)
test_size = len(dataset) - train_size
train, test = dataset[0: train_size, :], dataset[train_size: len(dataset), :]
print(len(train), len(test))
# Out:
# 1301 434

# %%
# 15. 转换array 值到dataset 矩阵
# X 是前一天的数据， y是后一天的数据
# 根据x计算出y值

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i: (i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i+look_back, 0])
    return np.array(dataX), np.array(dataY)

# reshape the train and test data
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# 打印shape

print('Shape of trainX: ', trainX.shape)
print('Shape of trainY: ', trainY.shape)
print('Shape of testX: ', testX.shape)
print('Shape of testY: ', testY.shape)
# Out:
# Shape of trainX:  (1299, 1)
# Shape of trainY:  (1299,)
# Shape of testX:  (432, 1)
# Shape of testY:  (432,)

# %%
# 这个数据的意义，通过回看昨天的数据，来预测今天的数据
# look_back = 1表示往回看一天

# 16. reshape
# Reshape the input array in the form - [Samples, time steps, features]
trainX = np.reshape(trainX, [trainX.shape[0], 1, trainX.shape[1]])
testX = np.reshape(testX, [testX.shape[0], 1, testX.shape[1]])

print('Shape of trainX: ', trainX.shape)
print('Shape of testX: ', testX.shape)
# Out:
# Shape of trainX:  (1299, 1, 1)
# Shape of testX:  (432, 1, 1)

# %%
# 17. 构建LSTM长短机模型

import tensorflow as tf
# 定义一个回调函数来保存验证集上表现最好的模型
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_model.h5',
    monitor='val_loss',  # 监控验证集上的损失函数
    save_best_only=True,  # 仅保存在验证集上表现最好的模型
    save_weights_only=False,  # 保存整个模型（包括模型架构）
    verbose=1  # 打印保存信息
)

model = Sequential()
model.add(LSTM(32, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=500, batch_size=32,  validation_data=(testX, testY), verbose=2, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/500
# 41/41 - 2s - loss: 9.3711 - val_loss: 7.7418
#
# Epoch 00001: val_loss improved from inf to 7.74182, saving model to best_model.h5
# Epoch 2/500
# 41/41 - 0s - loss: 6.4096 - val_loss: 4.8158
#
# Epoch 00002: val_loss improved from 7.74182 to 4.81581, saving model to best_model.h5
# Epoch 3/500
# 41/41 - 0s - loss: 3.5538 - val_loss: 2.2180
#
# Epoch 00003: val_loss improved from 4.81581 to 2.21804, saving model to best_model.h5
# Epoch 4/500
# 41/41 - 0s - loss: 1.3693 - val_loss: 0.6282
#
# Epoch 00004: val_loss improved from 2.21804 to 0.62822, saving model to best_model.h5
# Epoch 5/500
# 41/41 - 0s - loss: 0.3084 - val_loss: 0.0952
#
# Epoch 00005: val_loss improved from 0.62822 to 0.09519, saving model to best_model.h5
# Epoch 6/500
# 41/41 - 0s - loss: 0.0401 - val_loss: 0.0181
#
# Epoch 00006: val_loss improved from 0.09519 to 0.01809, saving model to best_model.h5
# Epoch 7/500
# 41/41 - 0s - loss: 0.0104 - val_loss: 0.0143
#
# Epoch 00007: val_loss improved from 0.01809 to 0.01426, saving model to best_model.h5
# Epoch 8/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00008: val_loss did not improve from 0.01426
# Epoch 9/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00009: val_loss did not improve from 0.01426
# Epoch 10/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00010: val_loss did not improve from 0.01426
# Epoch 11/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00011: val_loss did not improve from 0.01426
# Epoch 12/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00012: val_loss did not improve from 0.01426
# Epoch 13/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00013: val_loss did not improve from 0.01426
# Epoch 14/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00014: val_loss did not improve from 0.01426
# Epoch 15/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00015: val_loss did not improve from 0.01426
# Epoch 16/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00016: val_loss did not improve from 0.01426
# Epoch 17/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00017: val_loss did not improve from 0.01426
# Epoch 18/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00018: val_loss did not improve from 0.01426
# Epoch 19/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00019: val_loss did not improve from 0.01426
# Epoch 20/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00020: val_loss did not improve from 0.01426
# Epoch 21/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00021: val_loss did not improve from 0.01426
# Epoch 22/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00022: val_loss did not improve from 0.01426
# Epoch 23/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00023: val_loss did not improve from 0.01426
# Epoch 24/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00024: val_loss did not improve from 0.01426
# Epoch 25/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00025: val_loss did not improve from 0.01426
# Epoch 26/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00026: val_loss did not improve from 0.01426
# Epoch 27/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00027: val_loss did not improve from 0.01426
# Epoch 28/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00028: val_loss did not improve from 0.01426
# Epoch 29/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0143
#
# Epoch 00029: val_loss did not improve from 0.01426
# Epoch 30/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00030: val_loss did not improve from 0.01426
# Epoch 31/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00031: val_loss did not improve from 0.01426
# Epoch 32/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00032: val_loss did not improve from 0.01426
# Epoch 33/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0142
#
# Epoch 00033: val_loss improved from 0.01426 to 0.01425, saving model to best_model.h5
# Epoch 34/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00034: val_loss did not improve from 0.01425
# Epoch 35/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00035: val_loss did not improve from 0.01425
# Epoch 36/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00036: val_loss did not improve from 0.01425
# Epoch 37/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00037: val_loss did not improve from 0.01425
# Epoch 38/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00038: val_loss did not improve from 0.01425
# Epoch 39/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00039: val_loss did not improve from 0.01425
# Epoch 40/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00040: val_loss did not improve from 0.01425
# Epoch 41/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00041: val_loss did not improve from 0.01425
# Epoch 42/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00042: val_loss did not improve from 0.01425
# Epoch 43/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0144
#
# Epoch 00043: val_loss did not improve from 0.01425
# Epoch 44/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00044: val_loss did not improve from 0.01425
# Epoch 45/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0142
#
# Epoch 00045: val_loss improved from 0.01425 to 0.01424, saving model to best_model.h5
# Epoch 46/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0142
#
# Epoch 00046: val_loss did not improve from 0.01424
# Epoch 47/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00047: val_loss did not improve from 0.01424
# Epoch 48/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0142
#
# Epoch 00048: val_loss did not improve from 0.01424
# Epoch 49/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0142
#
# Epoch 00049: val_loss did not improve from 0.01424
# Epoch 50/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0142
#
# Epoch 00050: val_loss improved from 0.01424 to 0.01423, saving model to best_model.h5
# Epoch 51/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0144
#
# Epoch 00051: val_loss did not improve from 0.01423
# Epoch 52/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0144
#
# Epoch 00052: val_loss did not improve from 0.01423
# Epoch 53/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0143
#
# Epoch 00053: val_loss did not improve from 0.01423
# Epoch 54/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0142
#
# Epoch 00054: val_loss improved from 0.01423 to 0.01422, saving model to best_model.h5
# Epoch 55/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0142
#
# Epoch 00055: val_loss improved from 0.01422 to 0.01422, saving model to best_model.h5
# Epoch 56/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0142
#
# Epoch 00056: val_loss did not improve from 0.01422
# Epoch 57/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0142
#
# Epoch 00057: val_loss improved from 0.01422 to 0.01421, saving model to best_model.h5
# Epoch 58/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0142
#
# Epoch 00058: val_loss did not improve from 0.01421
# Epoch 59/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0142
#
# Epoch 00059: val_loss did not improve from 0.01421
# Epoch 60/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00060: val_loss did not improve from 0.01421
# Epoch 61/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00061: val_loss did not improve from 0.01421
# Epoch 62/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00062: val_loss improved from 0.01421 to 0.01421, saving model to best_model.h5
# Epoch 63/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0142
#
# Epoch 00063: val_loss did not improve from 0.01421
# Epoch 64/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00064: val_loss did not improve from 0.01421
# Epoch 65/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00065: val_loss did not improve from 0.01421
# Epoch 66/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00066: val_loss did not improve from 0.01421
# Epoch 67/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00067: val_loss did not improve from 0.01421
# Epoch 68/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00068: val_loss did not improve from 0.01421
# Epoch 69/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00069: val_loss did not improve from 0.01421
# Epoch 70/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00070: val_loss did not improve from 0.01421
# Epoch 71/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
# Epoch 00071: val_loss did not improve from 0.01421
# Epoch 72/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00072: val_loss improved from 0.01421 to 0.01420, saving model to best_model.h5
# Epoch 73/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00073: val_loss improved from 0.01420 to 0.01420, saving model to best_model.h5
# Epoch 74/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0145
#
# Epoch 00074: val_loss did not improve from 0.01420
# Epoch 75/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00075: val_loss improved from 0.01420 to 0.01420, saving model to best_model.h5
# Epoch 76/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00076: val_loss did not improve from 0.01420
# Epoch 77/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00077: val_loss did not improve from 0.01420
# Epoch 78/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0144
#
# Epoch 00078: val_loss did not improve from 0.01420
# Epoch 79/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00079: val_loss did not improve from 0.01420
# Epoch 80/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00080: val_loss did not improve from 0.01420
# Epoch 81/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00081: val_loss did not improve from 0.01420
# Epoch 82/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00082: val_loss improved from 0.01420 to 0.01419, saving model to best_model.h5
# Epoch 83/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00083: val_loss did not improve from 0.01419
# Epoch 84/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00084: val_loss improved from 0.01419 to 0.01419, saving model to best_model.h5
# Epoch 85/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00085: val_loss did not improve from 0.01419
# Epoch 86/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0143
#
# Epoch 00086: val_loss did not improve from 0.01419
# Epoch 87/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0142
#
# Epoch 00087: val_loss did not improve from 0.01419
# Epoch 88/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00088: val_loss improved from 0.01419 to 0.01419, saving model to best_model.h5
# Epoch 89/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00089: val_loss did not improve from 0.01419
# Epoch 90/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00090: val_loss did not improve from 0.01419
# Epoch 91/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00091: val_loss did not improve from 0.01419
# Epoch 92/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00092: val_loss did not improve from 0.01419
# Epoch 93/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0142
#
# Epoch 00093: val_loss did not improve from 0.01419
# Epoch 94/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0142
#
# Epoch 00094: val_loss did not improve from 0.01419
# Epoch 95/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0142
#
# Epoch 00095: val_loss did not improve from 0.01419
# Epoch 96/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0143
#
# Epoch 00096: val_loss did not improve from 0.01419
# Epoch 97/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0142
#
# Epoch 00097: val_loss did not improve from 0.01419
# Epoch 98/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00098: val_loss did not improve from 0.01419
# Epoch 99/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00099: val_loss did not improve from 0.01419
# Epoch 100/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0142
#
# Epoch 00100: val_loss did not improve from 0.01419
# Epoch 101/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0142
#
# Epoch 00101: val_loss did not improve from 0.01419
# Epoch 102/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0143
#
# Epoch 00102: val_loss did not improve from 0.01419
# Epoch 103/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00103: val_loss did not improve from 0.01419
# Epoch 104/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0142
#
# Epoch 00104: val_loss did not improve from 0.01419
# Epoch 105/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0142
#
# Epoch 00105: val_loss did not improve from 0.01419
# Epoch 106/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0142
#
# Epoch 00106: val_loss did not improve from 0.01419
# Epoch 107/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0142
#
# Epoch 00107: val_loss did not improve from 0.01419
# Epoch 108/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00108: val_loss did not improve from 0.01419
# Epoch 109/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00109: val_loss did not improve from 0.01419
# Epoch 110/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0143
#
# Epoch 00110: val_loss did not improve from 0.01419
# Epoch 111/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00111: val_loss did not improve from 0.01419
# Epoch 112/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00112: val_loss did not improve from 0.01419
# Epoch 113/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00113: val_loss did not improve from 0.01419
# Epoch 114/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00114: val_loss did not improve from 0.01419
# Epoch 115/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0142
#
# Epoch 00115: val_loss did not improve from 0.01419
# Epoch 116/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0142
#
# Epoch 00116: val_loss did not improve from 0.01419
# Epoch 117/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00117: val_loss did not improve from 0.01419
# Epoch 118/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00118: val_loss did not improve from 0.01419
# Epoch 119/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00119: val_loss did not improve from 0.01419
# Epoch 120/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00120: val_loss did not improve from 0.01419
# Epoch 121/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00121: val_loss did not improve from 0.01419
# Epoch 122/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00122: val_loss did not improve from 0.01419
# Epoch 123/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0142
#
# Epoch 00123: val_loss did not improve from 0.01419
# Epoch 124/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00124: val_loss did not improve from 0.01419
# Epoch 125/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00125: val_loss did not improve from 0.01419
# Epoch 126/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0143
#
# Epoch 00126: val_loss did not improve from 0.01419
# Epoch 127/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00127: val_loss did not improve from 0.01419
# Epoch 128/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00128: val_loss did not improve from 0.01419
# Epoch 129/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0149
#
# Epoch 00129: val_loss did not improve from 0.01419
# Epoch 130/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00130: val_loss did not improve from 0.01419
# Epoch 131/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00131: val_loss did not improve from 0.01419
# Epoch 132/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00132: val_loss did not improve from 0.01419
# Epoch 133/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0143
#
# Epoch 00133: val_loss did not improve from 0.01419
# Epoch 134/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00134: val_loss did not improve from 0.01419
# Epoch 135/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00135: val_loss did not improve from 0.01419
# Epoch 136/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00136: val_loss did not improve from 0.01419
# Epoch 137/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00137: val_loss did not improve from 0.01419
# Epoch 138/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00138: val_loss did not improve from 0.01419
# Epoch 139/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00139: val_loss did not improve from 0.01419
# Epoch 140/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00140: val_loss did not improve from 0.01419
# Epoch 141/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0150
#
# Epoch 00141: val_loss did not improve from 0.01419
# Epoch 142/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0143
#
# Epoch 00142: val_loss did not improve from 0.01419
# Epoch 143/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0148
#
# Epoch 00143: val_loss did not improve from 0.01419
# Epoch 144/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
# Epoch 00144: val_loss did not improve from 0.01419
# Epoch 145/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0149
#
# Epoch 00145: val_loss did not improve from 0.01419
# Epoch 146/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00146: val_loss did not improve from 0.01419
# Epoch 147/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00147: val_loss did not improve from 0.01419
# Epoch 148/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0143
#
# Epoch 00148: val_loss did not improve from 0.01419
# Epoch 149/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00149: val_loss did not improve from 0.01419
# Epoch 150/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00150: val_loss did not improve from 0.01419
# Epoch 151/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0145
#
# Epoch 00151: val_loss did not improve from 0.01419
# Epoch 152/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00152: val_loss did not improve from 0.01419
# Epoch 153/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00153: val_loss did not improve from 0.01419
# Epoch 154/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00154: val_loss did not improve from 0.01419
# Epoch 155/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0149
#
# Epoch 00155: val_loss did not improve from 0.01419
# Epoch 156/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0143
#
# Epoch 00156: val_loss did not improve from 0.01419
# Epoch 157/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00157: val_loss did not improve from 0.01419
# Epoch 158/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00158: val_loss did not improve from 0.01419
# Epoch 159/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0150
#
# Epoch 00159: val_loss did not improve from 0.01419
# Epoch 160/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00160: val_loss did not improve from 0.01419
# Epoch 161/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0150
#
# Epoch 00161: val_loss did not improve from 0.01419
# Epoch 162/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00162: val_loss did not improve from 0.01419
# Epoch 163/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00163: val_loss did not improve from 0.01419
# Epoch 164/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00164: val_loss did not improve from 0.01419
# Epoch 165/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0150
#
# Epoch 00165: val_loss did not improve from 0.01419
# Epoch 166/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00166: val_loss did not improve from 0.01419
# Epoch 167/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0145
#
# Epoch 00167: val_loss did not improve from 0.01419
# Epoch 168/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00168: val_loss did not improve from 0.01419
# Epoch 169/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00169: val_loss did not improve from 0.01419
# Epoch 170/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00170: val_loss did not improve from 0.01419
# Epoch 171/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00171: val_loss did not improve from 0.01419
# Epoch 172/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0147
#
# Epoch 00172: val_loss did not improve from 0.01419
# Epoch 173/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00173: val_loss did not improve from 0.01419
# Epoch 174/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00174: val_loss did not improve from 0.01419
# Epoch 175/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00175: val_loss did not improve from 0.01419
# Epoch 176/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0144
#
# Epoch 00176: val_loss did not improve from 0.01419
# Epoch 177/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00177: val_loss did not improve from 0.01419
# Epoch 178/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00178: val_loss did not improve from 0.01419
# Epoch 179/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00179: val_loss did not improve from 0.01419
# Epoch 180/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0144
#
# Epoch 00180: val_loss did not improve from 0.01419
# Epoch 181/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00181: val_loss did not improve from 0.01419
# Epoch 182/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00182: val_loss did not improve from 0.01419
# Epoch 183/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00183: val_loss did not improve from 0.01419
# Epoch 184/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00184: val_loss did not improve from 0.01419
# Epoch 185/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00185: val_loss did not improve from 0.01419
# Epoch 186/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00186: val_loss did not improve from 0.01419
# Epoch 187/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00187: val_loss did not improve from 0.01419
# Epoch 188/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00188: val_loss did not improve from 0.01419
# Epoch 189/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00189: val_loss did not improve from 0.01419
# Epoch 190/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00190: val_loss did not improve from 0.01419
# Epoch 191/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00191: val_loss did not improve from 0.01419
# Epoch 192/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0151
#
# Epoch 00192: val_loss did not improve from 0.01419
# Epoch 193/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00193: val_loss did not improve from 0.01419
# Epoch 194/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00194: val_loss did not improve from 0.01419
# Epoch 195/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00195: val_loss did not improve from 0.01419
# Epoch 196/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00196: val_loss did not improve from 0.01419
# Epoch 197/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00197: val_loss did not improve from 0.01419
# Epoch 198/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0148
#
# Epoch 00198: val_loss did not improve from 0.01419
# Epoch 199/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0147
#
# Epoch 00199: val_loss did not improve from 0.01419
# Epoch 200/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00200: val_loss did not improve from 0.01419
# Epoch 201/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00201: val_loss did not improve from 0.01419
# Epoch 202/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00202: val_loss did not improve from 0.01419
# Epoch 203/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0155
#
# Epoch 00203: val_loss did not improve from 0.01419
# Epoch 204/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0148
#
# Epoch 00204: val_loss did not improve from 0.01419
# Epoch 205/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00205: val_loss did not improve from 0.01419
# Epoch 206/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00206: val_loss did not improve from 0.01419
# Epoch 207/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0147
#
# Epoch 00207: val_loss did not improve from 0.01419
# Epoch 208/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00208: val_loss did not improve from 0.01419
# Epoch 209/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00209: val_loss did not improve from 0.01419
# Epoch 210/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00210: val_loss did not improve from 0.01419
# Epoch 211/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0151
#
# Epoch 00211: val_loss did not improve from 0.01419
# Epoch 212/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00212: val_loss did not improve from 0.01419
# Epoch 213/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0151
#
# Epoch 00213: val_loss did not improve from 0.01419
# Epoch 214/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0146
#
# Epoch 00214: val_loss did not improve from 0.01419
# Epoch 215/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0149
#
# Epoch 00215: val_loss did not improve from 0.01419
# Epoch 216/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0150
#
# Epoch 00216: val_loss did not improve from 0.01419
# Epoch 217/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00217: val_loss did not improve from 0.01419
# Epoch 218/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0150
# Epoch 00218: val_loss did not improve from 0.01419
# Epoch 219/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00219: val_loss did not improve from 0.01419
# Epoch 220/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00220: val_loss did not improve from 0.01419
# Epoch 221/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0145
#
# Epoch 00221: val_loss did not improve from 0.01419
# Epoch 222/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00222: val_loss did not improve from 0.01419
# Epoch 223/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0145
#
# Epoch 00223: val_loss did not improve from 0.01419
# Epoch 224/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00224: val_loss did not improve from 0.01419
# Epoch 225/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00225: val_loss did not improve from 0.01419
# Epoch 226/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00226: val_loss did not improve from 0.01419
# Epoch 227/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00227: val_loss did not improve from 0.01419
# Epoch 228/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00228: val_loss did not improve from 0.01419
# Epoch 229/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00229: val_loss did not improve from 0.01419
# Epoch 230/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00230: val_loss did not improve from 0.01419
# Epoch 231/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0149
#
# Epoch 00231: val_loss did not improve from 0.01419
# Epoch 232/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00232: val_loss did not improve from 0.01419
# Epoch 233/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0148
#
# Epoch 00233: val_loss did not improve from 0.01419
# Epoch 234/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00234: val_loss did not improve from 0.01419
# Epoch 235/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00235: val_loss did not improve from 0.01419
# Epoch 236/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00236: val_loss did not improve from 0.01419
# Epoch 237/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00237: val_loss did not improve from 0.01419
# Epoch 238/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00238: val_loss did not improve from 0.01419
# Epoch 239/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0152
#
# Epoch 00239: val_loss did not improve from 0.01419
# Epoch 240/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0145
#
# Epoch 00240: val_loss did not improve from 0.01419
# Epoch 241/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0150
#
# Epoch 00241: val_loss did not improve from 0.01419
# Epoch 242/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00242: val_loss did not improve from 0.01419
# Epoch 243/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00243: val_loss did not improve from 0.01419
# Epoch 244/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0145
#
# Epoch 00244: val_loss did not improve from 0.01419
# Epoch 245/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00245: val_loss did not improve from 0.01419
# Epoch 246/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00246: val_loss did not improve from 0.01419
# Epoch 247/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0145
#
# Epoch 00247: val_loss did not improve from 0.01419
# Epoch 248/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00248: val_loss did not improve from 0.01419
# Epoch 249/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00249: val_loss did not improve from 0.01419
# Epoch 250/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00250: val_loss did not improve from 0.01419
# Epoch 251/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00251: val_loss did not improve from 0.01419
# Epoch 252/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00252: val_loss did not improve from 0.01419
# Epoch 253/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00253: val_loss did not improve from 0.01419
# Epoch 254/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00254: val_loss did not improve from 0.01419
# Epoch 255/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00255: val_loss did not improve from 0.01419
# Epoch 256/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00256: val_loss did not improve from 0.01419
# Epoch 257/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0147
#
# Epoch 00257: val_loss did not improve from 0.01419
# Epoch 258/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00258: val_loss did not improve from 0.01419
# Epoch 259/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00259: val_loss did not improve from 0.01419
# Epoch 260/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00260: val_loss did not improve from 0.01419
# Epoch 261/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00261: val_loss did not improve from 0.01419
# Epoch 262/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0144
#
# Epoch 00262: val_loss did not improve from 0.01419
# Epoch 263/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00263: val_loss did not improve from 0.01419
# Epoch 264/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00264: val_loss did not improve from 0.01419
# Epoch 265/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00265: val_loss did not improve from 0.01419
# Epoch 266/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00266: val_loss did not improve from 0.01419
# Epoch 267/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00267: val_loss did not improve from 0.01419
# Epoch 268/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0146
#
# Epoch 00268: val_loss did not improve from 0.01419
# Epoch 269/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00269: val_loss did not improve from 0.01419
# Epoch 270/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00270: val_loss did not improve from 0.01419
# Epoch 271/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00271: val_loss did not improve from 0.01419
# Epoch 272/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00272: val_loss did not improve from 0.01419
# Epoch 273/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0149
#
# Epoch 00273: val_loss did not improve from 0.01419
# Epoch 274/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00274: val_loss did not improve from 0.01419
# Epoch 275/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0144
#
# Epoch 00275: val_loss did not improve from 0.01419
# Epoch 276/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00276: val_loss did not improve from 0.01419
# Epoch 277/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00277: val_loss did not improve from 0.01419
# Epoch 278/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0145
#
# Epoch 00278: val_loss did not improve from 0.01419
# Epoch 279/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00279: val_loss did not improve from 0.01419
# Epoch 280/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0145
#
# Epoch 00280: val_loss did not improve from 0.01419
# Epoch 281/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00281: val_loss did not improve from 0.01419
# Epoch 282/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00282: val_loss did not improve from 0.01419
# Epoch 283/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00283: val_loss did not improve from 0.01419
# Epoch 284/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00284: val_loss did not improve from 0.01419
# Epoch 285/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00285: val_loss did not improve from 0.01419
# Epoch 286/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00286: val_loss did not improve from 0.01419
# Epoch 287/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00287: val_loss did not improve from 0.01419
# Epoch 288/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0148
#
# Epoch 00288: val_loss did not improve from 0.01419
# Epoch 289/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0157
#
# Epoch 00289: val_loss did not improve from 0.01419
# Epoch 290/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0145
#
# Epoch 00290: val_loss did not improve from 0.01419
# Epoch 291/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00291: val_loss did not improve from 0.01419
# Epoch 292/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
# Epoch 00292: val_loss did not improve from 0.01419
# Epoch 293/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00293: val_loss did not improve from 0.01419
# Epoch 294/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0153
#
# Epoch 00294: val_loss did not improve from 0.01419
# Epoch 295/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00295: val_loss did not improve from 0.01419
# Epoch 296/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0148
#
# Epoch 00296: val_loss did not improve from 0.01419
# Epoch 297/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00297: val_loss did not improve from 0.01419
# Epoch 298/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0150
#
# Epoch 00298: val_loss did not improve from 0.01419
# Epoch 299/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0144
#
# Epoch 00299: val_loss did not improve from 0.01419
# Epoch 300/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00300: val_loss did not improve from 0.01419
# Epoch 301/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00301: val_loss did not improve from 0.01419
# Epoch 302/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0146
#
# Epoch 00302: val_loss did not improve from 0.01419
# Epoch 303/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00303: val_loss did not improve from 0.01419
# Epoch 304/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00304: val_loss did not improve from 0.01419
# Epoch 305/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00305: val_loss did not improve from 0.01419
# Epoch 306/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0146
#
# Epoch 00306: val_loss did not improve from 0.01419
# Epoch 307/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00307: val_loss did not improve from 0.01419
# Epoch 308/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00308: val_loss did not improve from 0.01419
# Epoch 309/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00309: val_loss did not improve from 0.01419
# Epoch 310/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0146
#
# Epoch 00310: val_loss did not improve from 0.01419
# Epoch 311/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00311: val_loss did not improve from 0.01419
# Epoch 312/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0145
#
# Epoch 00312: val_loss did not improve from 0.01419
# Epoch 313/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0148
#
# Epoch 00313: val_loss did not improve from 0.01419
# Epoch 314/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00314: val_loss did not improve from 0.01419
# Epoch 315/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00315: val_loss did not improve from 0.01419
# Epoch 316/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0148
#
# Epoch 00316: val_loss did not improve from 0.01419
# Epoch 317/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00317: val_loss did not improve from 0.01419
# Epoch 318/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00318: val_loss did not improve from 0.01419
# Epoch 319/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00319: val_loss did not improve from 0.01419
# Epoch 320/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00320: val_loss did not improve from 0.01419
# Epoch 321/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00321: val_loss did not improve from 0.01419
# Epoch 322/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00322: val_loss did not improve from 0.01419
# Epoch 323/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0150
#
# Epoch 00323: val_loss did not improve from 0.01419
# Epoch 324/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00324: val_loss did not improve from 0.01419
# Epoch 325/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00325: val_loss did not improve from 0.01419
# Epoch 326/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00326: val_loss did not improve from 0.01419
# Epoch 327/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0144
#
# Epoch 00327: val_loss did not improve from 0.01419
# Epoch 328/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00328: val_loss did not improve from 0.01419
# Epoch 329/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0149
#
# Epoch 00329: val_loss did not improve from 0.01419
# Epoch 330/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00330: val_loss did not improve from 0.01419
# Epoch 331/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00331: val_loss did not improve from 0.01419
# Epoch 332/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0145
#
# Epoch 00332: val_loss did not improve from 0.01419
# Epoch 333/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00333: val_loss did not improve from 0.01419
# Epoch 334/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00334: val_loss did not improve from 0.01419
# Epoch 335/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0144
#
# Epoch 00335: val_loss did not improve from 0.01419
# Epoch 336/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00336: val_loss did not improve from 0.01419
# Epoch 337/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00337: val_loss did not improve from 0.01419
# Epoch 338/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00338: val_loss did not improve from 0.01419
# Epoch 339/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0149
#
# Epoch 00339: val_loss did not improve from 0.01419
# Epoch 340/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00340: val_loss did not improve from 0.01419
# Epoch 341/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00341: val_loss did not improve from 0.01419
# Epoch 342/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00342: val_loss did not improve from 0.01419
# Epoch 343/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0149
#
# Epoch 00343: val_loss did not improve from 0.01419
# Epoch 344/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00344: val_loss did not improve from 0.01419
# Epoch 345/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0146
#
# Epoch 00345: val_loss did not improve from 0.01419
# Epoch 346/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00346: val_loss did not improve from 0.01419
# Epoch 347/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0151
#
# Epoch 00347: val_loss did not improve from 0.01419
# Epoch 348/500
# 41/41 - 0s - loss: 0.0092 - val_loss: 0.0151
#
# Epoch 00348: val_loss did not improve from 0.01419
# Epoch 349/500
# 41/41 - 0s - loss: 0.0094 - val_loss: 0.0148
#
# Epoch 00349: val_loss did not improve from 0.01419
# Epoch 350/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0153
#
# Epoch 00350: val_loss did not improve from 0.01419
# Epoch 351/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0145
#
# Epoch 00351: val_loss did not improve from 0.01419
# Epoch 352/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00352: val_loss did not improve from 0.01419
# Epoch 353/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0148
#
# Epoch 00353: val_loss did not improve from 0.01419
# Epoch 354/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00354: val_loss did not improve from 0.01419
# Epoch 355/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0145
#
# Epoch 00355: val_loss did not improve from 0.01419
# Epoch 356/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00356: val_loss did not improve from 0.01419
# Epoch 357/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0144
#
# Epoch 00357: val_loss did not improve from 0.01419
# Epoch 358/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00358: val_loss did not improve from 0.01419
# Epoch 359/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00359: val_loss did not improve from 0.01419
# Epoch 360/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00360: val_loss did not improve from 0.01419
# Epoch 361/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00361: val_loss did not improve from 0.01419
# Epoch 362/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00362: val_loss did not improve from 0.01419
# Epoch 363/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0150
#
# Epoch 00363: val_loss did not improve from 0.01419
# Epoch 364/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00364: val_loss did not improve from 0.01419
# Epoch 365/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00365: val_loss did not improve from 0.01419
# Epoch 366/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0148
# Epoch 00366: val_loss did not improve from 0.01419
# Epoch 367/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0146
#
# Epoch 00367: val_loss did not improve from 0.01419
# Epoch 368/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00368: val_loss did not improve from 0.01419
# Epoch 369/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00369: val_loss did not improve from 0.01419
# Epoch 370/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00370: val_loss did not improve from 0.01419
# Epoch 371/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00371: val_loss did not improve from 0.01419
# Epoch 372/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0152
#
# Epoch 00372: val_loss did not improve from 0.01419
# Epoch 373/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00373: val_loss did not improve from 0.01419
# Epoch 374/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00374: val_loss did not improve from 0.01419
# Epoch 375/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00375: val_loss did not improve from 0.01419
# Epoch 376/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0144
#
# Epoch 00376: val_loss did not improve from 0.01419
# Epoch 377/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0145
#
# Epoch 00377: val_loss did not improve from 0.01419
# Epoch 378/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00378: val_loss did not improve from 0.01419
# Epoch 379/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00379: val_loss did not improve from 0.01419
# Epoch 380/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00380: val_loss did not improve from 0.01419
# Epoch 381/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00381: val_loss did not improve from 0.01419
# Epoch 382/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00382: val_loss did not improve from 0.01419
# Epoch 383/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00383: val_loss did not improve from 0.01419
# Epoch 384/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00384: val_loss did not improve from 0.01419
# Epoch 385/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00385: val_loss did not improve from 0.01419
# Epoch 386/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0150
#
# Epoch 00386: val_loss did not improve from 0.01419
# Epoch 387/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0144
#
# Epoch 00387: val_loss did not improve from 0.01419
# Epoch 388/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0145
#
# Epoch 00388: val_loss did not improve from 0.01419
# Epoch 389/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00389: val_loss did not improve from 0.01419
# Epoch 390/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0147
#
# Epoch 00390: val_loss did not improve from 0.01419
# Epoch 391/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00391: val_loss did not improve from 0.01419
# Epoch 392/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00392: val_loss did not improve from 0.01419
# Epoch 393/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00393: val_loss did not improve from 0.01419
# Epoch 394/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0156
#
# Epoch 00394: val_loss did not improve from 0.01419
# Epoch 395/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00395: val_loss did not improve from 0.01419
# Epoch 396/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00396: val_loss did not improve from 0.01419
# Epoch 397/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00397: val_loss did not improve from 0.01419
# Epoch 398/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00398: val_loss did not improve from 0.01419
# Epoch 399/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0149
#
# Epoch 00399: val_loss did not improve from 0.01419
# Epoch 400/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00400: val_loss did not improve from 0.01419
# Epoch 401/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0146
#
# Epoch 00401: val_loss did not improve from 0.01419
# Epoch 402/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00402: val_loss did not improve from 0.01419
# Epoch 403/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00403: val_loss did not improve from 0.01419
# Epoch 404/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00404: val_loss did not improve from 0.01419
# Epoch 405/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00405: val_loss did not improve from 0.01419
# Epoch 406/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00406: val_loss did not improve from 0.01419
# Epoch 407/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00407: val_loss did not improve from 0.01419
# Epoch 408/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0145
#
# Epoch 00408: val_loss did not improve from 0.01419
# Epoch 409/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00409: val_loss did not improve from 0.01419
# Epoch 410/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00410: val_loss did not improve from 0.01419
# Epoch 411/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00411: val_loss did not improve from 0.01419
# Epoch 412/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0144
#
# Epoch 00412: val_loss did not improve from 0.01419
# Epoch 413/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0145
#
# Epoch 00413: val_loss did not improve from 0.01419
# Epoch 414/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00414: val_loss did not improve from 0.01419
# Epoch 415/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0146
#
# Epoch 00415: val_loss did not improve from 0.01419
# Epoch 416/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00416: val_loss did not improve from 0.01419
# Epoch 417/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00417: val_loss did not improve from 0.01419
# Epoch 418/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00418: val_loss did not improve from 0.01419
# Epoch 419/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0144
#
# Epoch 00419: val_loss did not improve from 0.01419
# Epoch 420/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0148
#
# Epoch 00420: val_loss did not improve from 0.01419
# Epoch 421/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00421: val_loss did not improve from 0.01419
# Epoch 422/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0151
#
# Epoch 00422: val_loss did not improve from 0.01419
# Epoch 423/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00423: val_loss did not improve from 0.01419
# Epoch 424/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00424: val_loss did not improve from 0.01419
# Epoch 425/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00425: val_loss did not improve from 0.01419
# Epoch 426/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00426: val_loss did not improve from 0.01419
# Epoch 427/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00427: val_loss did not improve from 0.01419
# Epoch 428/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00428: val_loss did not improve from 0.01419
# Epoch 429/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0145
#
# Epoch 00429: val_loss did not improve from 0.01419
# Epoch 430/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00430: val_loss did not improve from 0.01419
# Epoch 431/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00431: val_loss did not improve from 0.01419
# Epoch 432/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0154
#
# Epoch 00432: val_loss did not improve from 0.01419
# Epoch 433/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00433: val_loss did not improve from 0.01419
# Epoch 434/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0148
#
# Epoch 00434: val_loss did not improve from 0.01419
# Epoch 435/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00435: val_loss did not improve from 0.01419
# Epoch 436/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00436: val_loss did not improve from 0.01419
# Epoch 437/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0151
#
# Epoch 00437: val_loss did not improve from 0.01419
# Epoch 438/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00438: val_loss did not improve from 0.01419
# Epoch 439/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00439: val_loss did not improve from 0.01419
# Epoch 440/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
# Epoch 00440: val_loss did not improve from 0.01419
# Epoch 441/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00441: val_loss did not improve from 0.01419
# Epoch 442/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00442: val_loss did not improve from 0.01419
# Epoch 443/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00443: val_loss did not improve from 0.01419
# Epoch 444/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00444: val_loss did not improve from 0.01419
# Epoch 445/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0145
#
# Epoch 00445: val_loss did not improve from 0.01419
# Epoch 446/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0147
#
# Epoch 00446: val_loss did not improve from 0.01419
# Epoch 447/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00447: val_loss did not improve from 0.01419
# Epoch 448/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00448: val_loss did not improve from 0.01419
# Epoch 449/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00449: val_loss did not improve from 0.01419
# Epoch 450/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0147
#
# Epoch 00450: val_loss did not improve from 0.01419
# Epoch 451/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00451: val_loss did not improve from 0.01419
# Epoch 452/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00452: val_loss did not improve from 0.01419
# Epoch 453/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00453: val_loss did not improve from 0.01419
# Epoch 454/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00454: val_loss did not improve from 0.01419
# Epoch 455/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0144
#
# Epoch 00455: val_loss did not improve from 0.01419
# Epoch 456/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0148
#
# Epoch 00456: val_loss did not improve from 0.01419
# Epoch 457/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00457: val_loss did not improve from 0.01419
# Epoch 458/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0149
#
# Epoch 00458: val_loss did not improve from 0.01419
# Epoch 459/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00459: val_loss did not improve from 0.01419
# Epoch 460/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00460: val_loss did not improve from 0.01419
# Epoch 461/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00461: val_loss did not improve from 0.01419
# Epoch 462/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00462: val_loss did not improve from 0.01419
# Epoch 463/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00463: val_loss did not improve from 0.01419
# Epoch 464/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0153
#
# Epoch 00464: val_loss did not improve from 0.01419
# Epoch 465/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0146
#
# Epoch 00465: val_loss did not improve from 0.01419
# Epoch 466/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00466: val_loss did not improve from 0.01419
# Epoch 467/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00467: val_loss did not improve from 0.01419
# Epoch 468/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00468: val_loss did not improve from 0.01419
# Epoch 469/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00469: val_loss did not improve from 0.01419
# Epoch 470/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00470: val_loss did not improve from 0.01419
# Epoch 471/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0151
#
# Epoch 00471: val_loss did not improve from 0.01419
# Epoch 472/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0147
#
# Epoch 00472: val_loss did not improve from 0.01419
# Epoch 473/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00473: val_loss did not improve from 0.01419
# Epoch 474/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00474: val_loss did not improve from 0.01419
# Epoch 475/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00475: val_loss did not improve from 0.01419
# Epoch 476/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00476: val_loss did not improve from 0.01419
# Epoch 477/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00477: val_loss did not improve from 0.01419
# Epoch 478/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00478: val_loss did not improve from 0.01419
# Epoch 479/500
# 41/41 - 0s - loss: 0.0087 - val_loss: 0.0144
#
# Epoch 00479: val_loss did not improve from 0.01419
# Epoch 480/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00480: val_loss did not improve from 0.01419
# Epoch 481/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00481: val_loss did not improve from 0.01419
# Epoch 482/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0147
#
# Epoch 00482: val_loss did not improve from 0.01419
# Epoch 483/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00483: val_loss did not improve from 0.01419
# Epoch 484/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00484: val_loss did not improve from 0.01419
# Epoch 485/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0146
#
# Epoch 00485: val_loss did not improve from 0.01419
# Epoch 486/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0149
#
# Epoch 00486: val_loss did not improve from 0.01419
# Epoch 487/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00487: val_loss did not improve from 0.01419
# Epoch 488/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0150
#
# Epoch 00488: val_loss did not improve from 0.01419
# Epoch 489/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0149
#
# Epoch 00489: val_loss did not improve from 0.01419
# Epoch 490/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00490: val_loss did not improve from 0.01419
# Epoch 491/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0145
#
# Epoch 00491: val_loss did not improve from 0.01419
# Epoch 492/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0148
#
# Epoch 00492: val_loss did not improve from 0.01419
# Epoch 493/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0144
#
# Epoch 00493: val_loss did not improve from 0.01419
# Epoch 494/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0146
#
# Epoch 00494: val_loss did not improve from 0.01419
# Epoch 495/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0144
#
# Epoch 00495: val_loss did not improve from 0.01419
# Epoch 496/500
# 41/41 - 0s - loss: 0.0088 - val_loss: 0.0147
#
# Epoch 00496: val_loss did not improve from 0.01419
# Epoch 497/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0150
#
# Epoch 00497: val_loss did not improve from 0.01419
# Epoch 498/500
# 41/41 - 0s - loss: 0.0090 - val_loss: 0.0147
#
# Epoch 00498: val_loss did not improve from 0.01419
# Epoch 499/500
# 41/41 - 0s - loss: 0.0091 - val_loss: 0.0145
#
# Epoch 00499: val_loss did not improve from 0.01419
# Epoch 500/500
# 41/41 - 0s - loss: 0.0089 - val_loss: 0.0145
#
# Epoch 00500: val_loss did not improve from 0.01419

# %%
# 转换回原值

from keras.models import load_model

model = load_model('./best_model.h5')

# Make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# Invert predictions
trainPredict = np.expm1(trainPredict)
trainY = np.expm1(trainY)
testPredict = np.expm1(testPredict)
testY = np.expm1(testY)

# %%
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict[:, 0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY, testPredict[:, 0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 2.41 RMSE
# Test Score: 3.14 RMSE

# %%
# 这个结果是好的，test score要差些。
# 如果test score 比 train score要好些，过拟合了

# %%
# 查看是否偏差太大

test_series = pd.Series(testY)

if testScore < test_series.std():
    print('\n[Model performance is GOOD enough]')
    print('\nRMSE of test prediction < standard deviation of test dataset')
    print('%.2f' % (testScore), '<', '%.2f' % (test_series.std()))
else:
    print('\n[Model performance is NOT GOOD enough]')
    print('\nRMSE of test prediction > standard deviation of test dataset')
    print('%.2f' % (testScore), '>', '%.2f' % (test_series.std()))
# Out:
# [Model performance is GOOD enough]
#
# RMSE of test prediction < standard deviation of test dataset
# 3.14 < 4.40

# %%
# plot 
# testPredictPlot的来由
# 去掉TrainPredict的长度，
# 去掉一个train数据集的loopback，再去掉一个test数据集的一个loopback

# Shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# Shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(trainPredict) + (look_back*2) +1: len(dataset)-1, :] = testPredict

# Plot original dataset and predictions
# 共取15个点
time_axis = np.linspace(0, dataset.shape[0]-1, 15)
time_axis = np.array([int(i) for i in time_axis])
time_axisLab = np.array(df2.index, dtype='datetime64[D]')

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 2.1, 2])
ax.plot(np.expm1(dataset), label='Original Dataset')
ax.plot(trainPredictPlot, color='orange', label='Train Prediction')
ax.plot(testPredictPlot, color='red', label='Test Prediction')
ax.set_xticks(time_axis)
ax.set_xticklabels(time_axisLab[time_axis], rotation=45)
ax.set_xlabel('\nDate', fontsize=27, fontweight='bold')
ax.set_ylabel('ISPU', fontsize=27, fontweight='bold')
ax.legend(loc='best', prop={'size': 20})
ax.tick_params(size=10, labelsize=15)
ax.set_xlim(-1, 1735)

# fig.add_axes() 是 Matplotlib 中用于向 Figure 对象添加坐标轴的方法。它的语法如下：
# rect：一个四元组，表示新添加的坐标轴的位置和大小，格式为 (left, bottom, width, height)，取值范围在 0 到 1 之间，表示相对于 Figure 的位置和大小。
ax1 = fig.add_axes([2.3, 1.3, 1, 0.7])
ax1.plot(np.expm1(dataset), label='Original Dataset')
ax1.plot(testPredictPlot, color='red', label='Test Prediction')
ax1.set_xticks(time_axis)
ax1.set_xticklabels(time_axisLab[time_axis], rotation=45)
ax1.set_xlabel('\nDate', fontsize=27, fontweight='bold')
ax1.set_ylabel('ISPU', fontsize=27, fontweight='bold')
ax1.tick_params(size=10, labelsize=15)
ax1.set_xlim(1360, 1735)
# Out:
# (1360.0, 1735.0)
